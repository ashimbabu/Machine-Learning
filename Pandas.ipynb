# %%
Data Science 2082-04-29 (14-08-2025)

# %%
Data:
1. Structured data:
    data that is organized in rows and columns (like in tables)
    fixed schema: each column has defined data type(str,int,flot)
eg: excel, sql dtabases, csv files
id          name             age
1           a                27
2           b                26
tools often used
sql,excel,pandas-python library, data analysis, data manipulation - installed used- Data science, machine learning, data engineering

# %%
2. semi-structured data:
    data that has structure, but not strict as rows and columns 
    no fixed schema, but still organized using keys or tags
eg:json,xml,mangodb
id=123
{
    'name':'ashim',
    'age':'40',
    'skills':['python','AI']
}

# %%
3. Unstructured data:
    data without any predefined format or structure 
    cannot be stored traditional rows/columns
    often requires preprocessing or analysis(NLP,image recogination. etc)

# %%
# Pandas
-library used for data analysis and manipulation
what can pandas do:
-load the from files(csv,excel,json,sql etc)
-clean and transform messy data
-analyze and summarize data
-handle missing values
-merge,join,and reshape datasets

# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
# Key pandas data structures 
1. Series
a one-dimentional labeled array
# Out:
#   Cell In[9], line 2
#     1. Series
#        ^
# SyntaxError: invalid syntax

# %%
s=pd.Series([10,20,30,40,50,60,70,80,90])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# 6    70
# 7    80
# 8    90
# dtype: int64

# %% [markdown]
# 2. DataFrame-A two dimentional table like an Excel sheet or sql tables

# %%
data={
    'Name':['anjana','John'],
    'Age':[27,26]
}
df=pd.DataFrame(data)
df
# Out:
#      Name  Age
# 0  anjana   27
# 1    John   26

# %%
import pandas as pd

# %%
# load the data
df=pd.read_csv('heart.xls')
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
# Colaccy add data:
df1=pd.read_csv(r'C:\Users\Downloads\heart.xls')
df1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Colaccy add data:
# ----> 2 df1=pd.read_csv(r'C:\Users\Downloads\heart.xls')
#       3 df1
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
1. age
2. sex
3. cp: chest pain type (4 values)
    - Value 0: typical angina
    - Value 1: atypical angina
    - Value 2: non-angina pain
    - Value 3: asymptomatic
4. trestbps: resting blood pressure(in mm Hg on admission to the hospital
5. chol: serum cholestoral in mg/dl
6. fbs: fasting blood sugar > 120 mg/dl(1=true; 0=false)
7. restecg: resting electrocardiographic results (values 0,1,2)
    - Value 0: normal
    - Value 1: having ST-T wave abnormality (T-wave inversions and/or ST elevation or depression of>0.05 mV)
    - Value 2: Showing probable or definite left ventricular hypertrophy by Estes criteria
8. thalach: maximum heart rate achieved
9. exang: exercise induced angina
10. oldpeak: oldpeak = ST depression induced by exercise relative to rest
11. slope: the slope of the peak exercise ST segment
    - value 1: upsloping
    - value 2: flat
    - value 3: downsloping
12. ca: number of major vessels (0-3) colored by flourosopy
13. thal: 0 = normal; 1 = fixed defect; 2 = reversable defect
14. target: 0=less chance of heart attack, 1= more chance of heart attack
- The names and social security numbers of the patients were recently removed from the database, replaced with dummy values.

# %%
2. View the data
# Out:
#   Cell In[15], line 1
#     2. View the data
#        ^
# SyntaxError: invalid syntax

# %%
# peek at the top/bottom rows
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
# 5   58    0   0       100   248    0        0      122      0      1.0      1
# 6   58    1   0       114   318    0        2      140      0      4.4      0
# 7   55    1   0       160   289    0        0      145      1      0.8      1
# 8   46    1   0       120   249    0        0      144      0      0.8      2
# 9   54    1   0       122   286    0        0      116      1      3.2      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# ...

# %%
df.tail(3)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
# view random rows
df.sample(12)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 111   53    1   0       142   226    0        0      111      1      0.0
# 537   52    1   1       120   325    0        1      172      0      0.2
# 920   39    1   0       118   219    0        1      140      0      1.2
# 996   56    0   0       134   409    0        0      150      1      1.9
# 291   58    1   0       128   259    0        0      130      1      3.0
# 893   52    1   0       128   204    1        1      156      1      1.0
# 510   54    0   1       132   288    1        0      159      1      0.0
# 957   50    1   2       140   233    0        1      163      0      0.6
# 163   48    1   0       124   274    0        0      166      0      0.5
# 257   64    0   0       180   325    0        1      154      1      0.0
# 599   63    0   1       140   195    0        1      179      0      0.0
# 741   41    0   2       112   268    0        0      172      1      0.0
#
# ...

# %%
3. Understand the structure
# Out:
#   Cell In[20], line 1
#     3. Understand the structure
#        ^
# SyntaxError: invalid syntax

# %%
# shape of dataset(no. of rows and no. of columns)
df.shape
# Out:
# (1025, 14)

# %%
# to find all the columns name
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
# data types of columns
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
# overall information of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
# summary statistics (for numeric columns)
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
# summary statistics (for numeric columns)
df.describe().loc['mean']
# Out:
# age          54.434146
# sex           0.695610
# cp            0.942439
# trestbps    131.611707
# chol        246.000000
# fbs           0.149268
# restecg       0.529756
# thalach     149.114146
# exang         0.336585
# oldpeak       1.071512
# slope         1.385366
# ca            0.754146
# thal          2.323902
# target        0.513171
# Name: mean, dtype: float64

# %%
# Acess columns
df[['age','cp']]
# Out:
#       age  cp
# 0      52   0
# 1      53   0
# 2      70   0
# 3      61   0
# 4      62   0
# ...   ...  ..
# 1020   59   1
# 1021   60   0
# 1022   47   0
# 1023   50   0
# 1024   54   0
#
# [1025 rows x 2 columns]

# %%
# Access columns info
# calculate average of columns
df['age'].mean()
# Out:
# np.float64(54.43414634146342)

# %%
# max() to find maximum values in the dataset
df['age'].max()
# Out:
# np.int64(77)

# %%
# max() to find minimum values in the dataset
df['age'].min()
# Out:
# np.int64(29)

# %%
# check for the missing data
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
# check for duplicates values
df.duplicated().sum()
# Out:
# np.int64(723)

# %%
# remove the duplicates values
df=df.drop_duplicates()

# %%
df[['age','sex']]
# Out:
#       age  sex
# 0      52    1
# 1      53    1
# 2      70    1
# 3      61    1
# 4      62    0
# ...   ...  ...
# 1020   59    1
# 1021   60    1
# 1022   47    1
# 1023   50    0
# 1024   54    1
#
# [1025 rows x 2 columns]

# %%
df.iloc[12:48]
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 12   34    0   1       118   210    0        1      192      0      0.7
# 13   51    1   0       140   298    0        1      122      1      4.2
# 14   52    1   0       128   204    1        1      156      1      1.0
# 15   34    0   1       118   210    0        1      192      0      0.7
# 16   51    0   2       140   308    0        0      142      0      1.5
# 17   54    1   0       124   266    0        0      109      1      2.2
# 18   50    0   1       120   244    0        1      162      0      1.1
# 19   58    1   2       140   211    1        0      165      0      0.0
# 20   60    1   2       140   185    0        0      155      0      3.0
# 21   67    0   0       106   223    0        1      142      0      0.3
# 22   45    1   0       104   208    0        0      148      1      3.0
# 23   63    0   2       135   252    0        0      172      0      0.0
# ...

# %%
# Filtering Data
df[df['age'] < 30]
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 60   29    1   1       130   204    0        0      202      0      0.0
#
#     slope  ca  thal  target
# 60      2   0     2       1

# %%
df11=df[(df['age']>=30) & (df['age']<=40)]
df11
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 12    34    0   1       118   210    0        1      192      0      0.7
# 52    38    1   2       138   175    0        1      173      0      0.0
# 68    37    0   2       120   215    0        1      170      0      0.0
# 108   40    1   0       152   223    0        1      181      0      0.0
# 143   34    1   3       118   182    0        0      174      0      0.0
# 145   40    1   0       110   167    0        0      114      1      2.0
# 149   39    1   2       140   321    0        0      182      0      0.0
# 156   40    1   3       140   199    0        1      178      1      1.4
# 173   39    0   2        94   199    0        1      179      0      0.0
# 248   39    0   2       138   220    0        1      152      0      0.0
# 254   35    1   0       120   198    0        1      130      1      1.6
# 256   35    0   0       138   183    0        1      182      0      1.4
# ...

# %%
df11.shape
# Out:
# (17, 14)

# %%
df11=df[(df['age']>=40) & (df['age']<=50)]
df11
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 8     46    1   0       120   249    0        0      144      0      0.8
# 11    43    0   0       132   341    1        0      136      1      3.0
# 18    50    0   1       120   244    0        1      162      0      1.1
# 22    45    1   0       104   208    0        0      148      1      3.0
# 24    42    0   2       120   209    0        1      173      0      0.0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 541   44    1   2       140   235    0        0      180      0      0.0
# 566   50    0   0       110   254    0        0      159      0      0.0
# 580   46    1   1       101   197    1        1      156      0      0.0
# 616   43    1   0       115   303    0        1      181      0      1.2
# 733   44    0   2       108   141    0        1      175      0      0.6
#
#      slope  ca  thal  target
# 8        2   0     3       0
# 11       1   0     3       0
# ...

# %%
df11.shape
# Out:
# (79, 14)

# %%
df11=df[(df['age']>=50) & (df['age']<=60)]
df11
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1      168      0      1.0
# 1     53    1   0       140   203    1        0      155      1      3.1
# 5     58    0   0       100   248    0        0      122      0      1.0
# 6     58    1   0       114   318    0        2      140      0      4.4
# 7     55    1   0       160   289    0        0      145      1      0.8
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 708   60    0   2       120   178    1        1       96      0      0.0
# 719   52    1   0       108   233    1        1      147      0      0.1
# 739   52    1   0       128   255    0        1      161      1      0.0
# 843   59    1   3       160   273    0        0      125      0      0.0
# 878   54    1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# ...

# %%
df11.shape
# Out:
# (136, 14)

# %%
# Adding or removing columns 
df['salary']=df['trestbps']+df['chol']

# %%
# Drop the column
df.drop('salary',axis=1,inplace=True)

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1      168      0      1.0
# 1     53    1   0       140   203    1        0      155      1      3.1
# 2     70    1   0       145   174    0        1      125      1      2.6
# 3     61    1   0       148   203    0        1      161      0      0.0
# 4     62    0   0       138   294    1        1      106      0      1.9
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 723   68    0   2       120   211    0        0      115      0      1.5
# 733   44    0   2       108   141    0        1      175      0      0.6
# 739   52    1   0       128   255    0        1      161      1      0.0
# 843   59    1   3       160   273    0        0      125      0      0.0
# 878   54    1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# ...

# %%
# sorting data
df.sort_values('chol')
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 101   57    1   2       150   126    1        1      173      0      0.2
# 32    57    1   0       130   131    0        1      115      1      1.2
# 733   44    0   2       108   141    0        1      175      0      0.6
# 81    49    1   2       118   149    0        0      126      0      0.8
# 10    71    0   0       112   149    0        1      125      0      1.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 255   62    0   0       140   394    0        0      157      0      1.2
# 450   63    0   0       150   407    0        0      154      0      4.0
# 179   56    0   0       134   409    0        0      150      1      1.9
# 123   65    0   2       140   417    1        0      157      0      0.8
# 158   67    0   2       115   564    0        0      160      0      1.6
#
#      slope  ca  thal  target
# 101      2   1     3       1
# 32       1   1     3       0
# ...

# %%
df.sort_values('chol',ascending=False).head(10)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 158   67    0   2       115   564    0        0      160      0      1.6
# 123   65    0   2       140   417    1        0      157      0      0.8
# 179   56    0   0       134   409    0        0      150      1      1.9
# 450   63    0   0       150   407    0        0      154      0      4.0
# 255   62    0   0       140   394    0        0      157      0      1.2
# 40    65    0   2       160   360    0        0      151      0      0.8
# 167   57    0   0       120   354    0        1      163      1      0.6
# 252   55    1   0       132   353    0        1      132      1      1.2
# 44    55    0   1       132   342    0        1      166      0      1.2
# 11    43    0   0       132   341    1        0      136      1      3.0
#
#      slope  ca  thal  target
# 158      1   0     3       1
# 123      2   1     2       1
# 179      1   2     3       0
# 450      1   3     3       0
# ...

# %%
df['age'].mean()
# Out:
# np.float64(54.420529801324506)

# %%
df['age'].max()
# Out:
# np.int64(77)

# %%
df['age'].min()
# Out:
# np.int64(29)

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
df.to_csv('output.csv')

# %%
df.to_csv('output_index.csv',index=False)

# %%
Summary table
task                 command
read csv             pd.read_csv('file.csv')
view data            df.head(),df.tail(),df.sample()
select column        df['col']
filter row           df[df['col']] > val]
add columns          df['new_column']=values
remove column        df.drop('col',axis=1)
sort data            df.sort_values('col')
export csv           df.to_csv('file.csv',index=False)
