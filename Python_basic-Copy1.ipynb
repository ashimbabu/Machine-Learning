# %%
# display any thing
print(20)
# Out:
# 20

# %%
print('ABC')
# Out:
# ABC

# %% [markdown]
# # Variable
# - is a name that stores some values
# # How to declare a variable in python
# a=20

# %%
a=10
b=30
c='XYZ'

# %%
print(a)
print(b)
print(c)
# Out:
# 10
# 30
# XYZ

# %% [markdown]
# # Data type in python
# integer-int() whole number
# float -decimal number 10.34,34,5,60.0
# string- str anything the is not a number('1234r','Ashim','this is a data science class')
# bool-boolean true or False

# %%
a=20
b=30
c=a+b
print('This is sum of two numbers :',c,'First number is:'a, 'Second number is:'b)
# Out:
#   Cell In[11], line 4
#     print('This is sum of two numbers :',c,'First number is:'a, 'Second number is:'b)
#                                            ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# # Take input from user
# input()

# %%
a=float(input('enter a 1st number'))
b=float(input('enter a 2nd number'))
sum=a+b
print('sum is',sum)

# %% [markdown]
# # enter 3 input from user and perform multiplication and display the results

# %%
a=float(input('enter a 1st number'))
b=float(input('enter a 2nd number'))
c=float(input('enter a 3nd number'))
sum=a*b*c
print('multi is',sum)

# %% [markdown]
# # Operators
# -are special symbol or keywords to perform operations on variables and value
# 1.Arithmetic operators
# -basic math operators

# %% [markdown]
# # Arithmetic operators
# operators                   meaning                     example
# +                           addition
# -                           subtraction
# *                           multiply
# /                           division
# //                          floor Division             5//2=2
# %                           modules                    5%2=1
# **                          exponent(power)            2**2=4

# %%
a=23
b=10
print('normal division',a/b)
print('floor division',a//b)
print('reminder',a%b)
print('power',a**b)

# %% [markdown]
# # Addition
# a=float(input('enter a 1st number'))
# b=float(input('enter a 2nd number'))
# c=float(input('enter a 3nd number'))
# sum=a+b+c
# print('sum is',sum)

# %% [markdown]
# # Substraction
# a=float(input('enter a 1st number'))
# b=float(input('enter a 2nd number'))
# c=float(input('enter a 3nd number'))
# sum=a-b-c
# print('substraction is',sum)

# %% [markdown]
# # Multiply
# a=float(input('enter a 1st number'))
# b=float(input('enter a 2nd number'))
# c=float(input('enter a 3nd number'))
# sum=a*b*c
# print('multi is',sum)

# %% [markdown]
# # Division
# a=float(input('enter a 1st number'))
# b=float(input('enter a 2nd number'))
# c=float(input('enter a 3nd number'))
# sum=a/b/c
# print('division is',sum)

# %% [markdown]
# # Floor Division
# a=float(input('enter a 1st number'))
# b=float(input('enter a 2nd number'))
# c=float(input('enter a 3nd number'))
# sum=a//b//c
# print('floor division is',sum)

# %% [markdown]
# # Modules
# a=float(input('enter a 1st number'))
# b=float(input('enter a 2nd number'))
# c=float(input('enter a 3nd number'))
# sum=a%b%c
# print('modules is',sum)

# %% [markdown]
# # Exponent(Power)
# a=float(input('enter a 1st number'))
# b=float(input('enter a 2nd number'))
# c=float(input('enter a 3nd number'))
# sum=a**b**c
# print('exponent (power) is',sum)
