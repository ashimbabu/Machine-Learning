# %%
import pandas as pd

# %%
df=pd.read_csv('heart.xls')

# %%
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
# KNN- k nearest neighbours
-lazy learning means it doesnot learn a model upfront.Instead, it makes predictions based on the stored training data
how:
-choose k- the number of neighbout(2,3,4,6,7,8 etc)
- measure the distance
- find k nearest neighbors
vote/average
Feature X                    Feature Y                 Class
2                             3                         A
3                             4                         A
5                             6                         B
6                             7                         B
# Out:
#   Cell In[4], line 2
#     -lazy learning means it doesnot learn a model upfront.Instead, it makes predictions based on the stored training data
#           ^
# SyntaxError: invalid syntax

# %%
4,5
1. compute the distance to all points
d=(x2-x1)**2+(y2-y1)**2^1/2
a.(2,3)---------------(4-2)**2+(5-3)**2^1/2 = 2.82 A
b.(3,4)---------------1.4 A
c.(5,6)..............1.41 B
d.(6,7)...............2.82 B

step=find k=3 nearest neighbours

(3,4)-A,(5,6)-B,(2,3)-A
A-2
B-1

majority=A
classify=A

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.drop('target',axis=1)
y=df['target']

# %%
# split data
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
#train the model
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train,y_train)

# %%
# predict
y_pred=knn.predict(X_test)

# %%
Y_pred_train=knn.predict(X_train)

# %%
accuracy_score(y_train,Y_pred_train)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)

# %%
# Regualization 
- a techniques to reduce overfitting by adding a penalty to large coefficients calues in regression model

# %%
from sklearn.linear_model import Ridge, Lasso
ridge=Ridge(alpha=1.0)
ridge.fit(X_train,y_train)

# %%
alpha=0, no reagularization
alpha small(0.001-0.1)= light penalty    ---- coefficients are slightly shrunk
alpha moderate(0.1-10)= balanced panelty  -----helps control overfitting
alpha large(10-100 or higher) strong penalty ----coefficients become very small or 0

# %%
pre=ridge.predict(X_train)

# %%
pre_test=ridge.predict(X_test)

# %%
pip install numpy

# %%
import numpy as np

# %%
# creating arrays 
arr1=np.array([1,2,3,4])
arr1

# %%
arr2=np.array([[1,2,3],[3,4,6],[7,8,9]])
arr2

# %%
arr2.shape

# %%
arr2[1,2]

# %%
arr2[2,1]

# %%
arr2[1]

# %%
arr2[:,1]

# %%
arr=np.arrange(0,10,2)
print(arr)

# %%
np.random.rand(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 np.random.rand(5)
#
# NameError: name 'np' is not defined

# %%
np.random.randint(0,10,7)

# %%
np.zeros(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 np.zeros(5)
#
# NameError: name 'np' is not defined

# %%
# array with specific value
np.full((2,3,),7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # array with specific value
# ----> 2 np.full((2,3,),7)
#
# NameError: name 'np' is not defined

# %%
np.arrange(1,7).reshape(2,3)
arr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 np.arrange(1,7).reshape(2,3)
#       2 arr
#
# NameError: name 'np' is not defined

# %%
arr+2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 arr+2
#
# NameError: name 'arr' is not defined

# %%
arr*3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 arr*3
#
# NameError: name 'arr' is not defined

# %%
arr.sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 arr.sum()
#
# NameError: name 'arr' is not defined

# %%
# mean of each column
arr.mean(axis=0)

# %%
# mean of each row
arr.mean(axis=1)

# %%
np.random.seed(42)
data=pd.DataFrame({
    'credit_score':np.random.randint(300,851,200),
    'employment_years':np.random.randint(0,41,200),
    'gender':np.random.choice(['Male,Female'],200)
})
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 np.random.seed(42)
#
# NameError: name 'np' is not defined
