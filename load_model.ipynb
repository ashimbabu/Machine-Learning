# %%
import joblib

# %%
model=joblib.load('random_forest_life_exp.pkl')

# %%
data={'Country':[5,6], 'Year':[2014,2012], 'Status':[1,0], 'Adult Mortality':[29,123], 'Alcohol':[2,3.4],
       'Hepatitis B':[56,67], 'Measles ':[120,100], ' BMI ':[26.6,34], 'under-five deaths ':[23,56], 'Polio':[67,89],
       'Total expenditure':[4.81,4.89], 'Diphtheria ':[89,90], ' HIV/AIDS':[1.2,1.3], 'GDP':[1234,5678], 'Population':[123456,345678],
       ' thinness  1-19 years':[6.9,2.3], 'Schooling':[10.9,12.1]}

# %%
import pandas as pd
df_new=pd.DataFrame(data)

# %%
model.predict(df_new)
# Out:
# array([61.581, 64.318])
