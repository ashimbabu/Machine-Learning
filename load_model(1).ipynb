# %%
import joblib

# %%
model=joblib.load('random_forest_life_exp.pkl')

# %%
data={'Country':[104,120], 'Year':[2012,2014], 'Status':[1,0], 'Adult Mortality':[126,256], 'Alcohol':[4.3,7.7],
       'Hepatitis B':[95,86], 'Measles ':[1,340], ' BMI ':[28,89], 'under-five deaths ':[0,120], 'Polio':[83,92],
       'Total expenditure':[5,9], 'Diphtheria ':[80,92], ' HIV/AIDS':[0.1,7.5], 'GDP':[1234,4567], 'Population':[123456,345678],
       ' thinness  1-19 years':[2,5.5], 'Schooling':[3.3,5.5]}

# %%
import pandas as pd
df_new=pd.DataFrame(data)

# %%
model.predict(df_new)
# Out:
# array([72.413, 62.169])
