# %%
import pandas as pd

# %%
df=pd.read_csv('Mall_Customers.csv')
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %% [markdown]
# # Common unsupervised algorithms
# 1. clustering:
# groups similar items together based on distance or similarity
# -k-means
# -hierarchical clustering
# -dbscan

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Univariate analysis
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.hisplot(df['Age'])

# %%
# bivariate relationships
sns.scatterplot(x='Annual Income (k$)',y='')

# %%
df.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
# drop id
df.drop('CustomerID',axis=1,inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 2
#       1 # drop id
# ----> 2 df.drop('CustomerID',axis=1,inplace=True)
#       3 df
#
# AttributeError: 'NoneType' object has no attribute 'drop'

# %%
df['Gender']=df['Gender'].map({})

# %%
df.dtypes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df.dtypes
#
# AttributeError: 'NoneType' object has no attribute 'dtypes'

# %%
sns.boxplot(x='Age',data=df)
sns.boxplot(x='Annual Income (k$)',data=df)
sns.boxplot(x='',data=df)

# %%
Q1=df['Annual Income (k$)'].quantile(0.25)
Q3=df['Annual Income (k$)'].quantile(0.75)

# %%
IQR=Q3-Q1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 IQR=Q3-Q1
#
# NameError: name 'Q3' is not defined

# %%
lower_bound=Q1-1.5*IQR
upper_bound=Q1+1.5*IQR
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 lower_bound=Q1-1.5*IQR
#       2 upper_bound=Q1+1.5*IQR
#
# NameError: name 'Q1' is not defined

# %%
df(df['Annual Income (k$)']<=lower_bound) | (df['Annual Income (k$)']>=upper_bound)]
# Out:
#   Cell In[15], line 1
#     (df['Annual Income (k$)']<=lower_bound) | (df['Annual Income (k$)']>=upper_bound)]
#                                                                                      ^
# SyntaxError: unmatched ']'

# %%
lower_bound
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 lower_bound
#
# NameError: name 'lower_bound' is not defined

# %%
upper_bound
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 upper_bound
#
# NameError: name 'upper_bound' is not defined

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df.columns
#
# AttributeError: 'NoneType' object has no attribute 'columns'

# %%
df['Annual Income (k$)']=df['Annual Income (k$)'].clip(lower=lower_bound,upper=upper_bound)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df['Annual Income (k$)']=df['Annual Income (k$)'].clip(lower=lower_bound,upper=upper_bound)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
df

# %%
common scaling Techniques:
min_max scaling -scales data to [0,1] range
standardization -centers data to mean=0, std=1

# %%
from sklearn.preprocessing import StandardScaler # MinMaxScaler

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df.columns
#
# AttributeError: 'NoneType' object has no attribute 'columns'

# %%
cols['Age','Annual Income (k$)','Spending Score (1-100)']

# %%
scaler=StandScaler() # MinMaxScalar
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 scaler=StandScaler()
#
# NameError: name 'StandScaler' is not defined

# %%
df[cols]=scaler.fit_transform(df[cols])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df[cols]=scaler.fit_transform(df[cols])
#
# NameError: name 'scaler' is not defined

# %%
#elbo method
from sklearn.cluster import kMeans
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 #elbo method
# ----> 2 from sklearn.cluster import kmeans
#
# ImportError: cannot import name 'kmeans' from 'sklearn.cluster' (C:\Users\acer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\cluster\__init__.py)

# %%
inertia=[]
for k in range(1,11):
    kmeans=KMeans(n_clusters=k,random_state=42)
    kmeans.fit(df)
    inertia.append(kmeans.inertia_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 inertia=[]
#       2 for k in range(1,11):
# ----> 3     kmeans=KMeans(n_clusters=k,random_state=42)
#       4     kmeans.fit(df)
#       5     inertia.append(kmeans.inertia_)
#
# NameError: name 'KMeans' is not defined

# %%
import matplotlib.pyplot as plt

# %%
k_range=range(1,11)
plt.plot(k_range,inertia)
plt.xlabel('number of clusters (K)')
plt.ylabel('inertia (WCSS)')
plt.title('elbow method for k')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 k_range=range(1,11)
# ----> 2 plt.plot(k_range,inertia)
#       3 plt.xlabel('number of clusters (K)')
#       4 plt.ylabel('inertia (WCSS)')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:3838, in plot(scalex, scaley, data, *args, **kwargs)
#    3830 @_copy_docstring_and_deprecators(Axes.plot)
#    3831 def plot(
#    3832     *args: float | ArrayLike | str,
#    (...)   3836     **kwargs,
#    3837 ) -> list[Line2D]:
# -> 3838     return gca().plot(
#    3839         *args,
#    3840         scalex=scalex,
#    3841         scaley=scaley,
#    3842         **({"data": data} if data is not None else {}),
#    3843         **kwargs,
#    3844     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axes\_axes.py:1777, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1534 """
#    1535 Plot y versus x as lines and/or markers.
#    1536
#    (...)   1774 (``'green'``) or hex strings (``'#008000'``).
#    1775 """
#    1776 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778 for line in lines:
#    1779     self.add_line(line)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axes\_base.py:297, in _process_plot_var_args.__call__(self, axes, data, return_kwargs, *args, **kwargs)
#     295     this += args[0],
#     296     args = args[1:]
# --> 297 yield from self._plot_args(
#     298     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey,
#     299     return_kwargs=return_kwargs
#     300 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axes\_base.py:494, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     491     axes.yaxis.update_units(y)
#     493 if x.shape[0] != y.shape[0]:
# --> 494     raise ValueError(f"x and y must have same first dimension, but "
#     495                      f"have shapes {x.shape} and {y.shape}")
#     496 if x.ndim > 2 or y.ndim > 2:
#     497     raise ValueError(f"x and y can be no greater than 2D, but have "
#     498                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (10,) and (0,)

# %%
kmeans=kMeans(n_clusters=4,random_state=42)
kmeans.fit(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 kmeans=kmeans(n_clusters=4,random_state=42)
#       2 kmeans.fit(df)
#
# NameError: name 'kmeans' is not defined

# %%
labels=kmeans.fit_predict(df)

# %%
from sklearn.metrics import silhouette_score

# %%
score=silhouette_score(df,labels)
print('silhouette_score',score)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 score=silhouette_score(df,labels)
#       2 print('silhouette_score',score)
#
# NameError: name 'silhouette_score' is not defined

# %%
df['cluster']=labels
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df['cluster']=labels
#
# NameError: name 'labels' is not defined

# %%
# Dimention detection
